# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4,5])
y=x

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y
# Out:
# array([1, 2, 3, 4, 5])

# %%
plt.figure(1)
plt.subplot(221)
plt.title("221")
plt.plot(x,y,"r-")
plt.subplot(222)
plt.title("222")
plt.plot(x,y*2,"bo")
plt.subplot(223)
plt.title("223")
plt.plot(x,y*3,"g^")
plt.show()

# %%
a=np.linspace(1,10,5,dtype=int)
b=a

# %%
a
# Out:
# array([ 1,  3,  5,  7, 10])

# %%
b
# Out:
# array([ 1,  3,  5,  7, 10])

# %%
plt.figure(2)
plt.subplot(221)
plt.title("Linear")
plt.plot(a,a)

plt.subplot(222)
plt.title("Cubic")
plt.plot(a,a**3)

plt.subplot(223)
plt.title("Log")
plt.plot(a,np.log(a))

plt.subplot(224)
plt.title("Exponential")
plt.plot(a,a**2)

# %%
import seaborn as sb

# %%
sb.set_style("whitegrid")

# %%
sb.distplot([1,2,2,3,4,5,5,5],rug=True,hist=False)
plt.show()

# %%
sb.boxplot(y=[1,2,2,3,4,4,4,5])

# %%
df=pd.read_csv("E:/tuts/FreeCourseSite.com  Udemy - Machine Learning A-Z  Become Kaggle Master/7. Data Visualisation/Datavisual/global_sales_data/market_fact.csv")

# %%
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
plt.subplot(2,2,4)
plt.title("Shipping_Cost")
sb.distplot(df["Shipping_Cost"])

plt.subplot(2,2,2)
plt.title("Profit")
sb.distplot(df["Profit"])

plt.subplot(2,2,3)
plt.title("Order_Quantity")
sb.distplot(df["Order_Quantity"])

plt.subplot(2,2,1)
plt.title("Sales")
sb.distplot(df["Sales"])
plt.show()

# %%
sb.jointplot("Sales","Profit",df)

# %%
conditonal_df=df[(df.Sales<10000) & (df.Profit<20000)]

# %%
sb.jointplot("Sales","Profit",conditonal_df)
plt.show()

# %%
plt.hist([1,2,2,2,3,3,4,5,6],)
# Out:
# (array([1., 0., 3., 0., 2., 0., 1., 0., 1., 1.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <a list of 10 Patch objects>)
